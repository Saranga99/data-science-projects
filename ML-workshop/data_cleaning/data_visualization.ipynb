# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#a simple line chart
L1=[1,2,3,4]
L2=[10,30,32,59]

# %%
plt.plot(L1,L2)
plt.title("Simple Line Chart")
plt.xlabel("Index")
plt.ylabel("Value")
plt.show()

# %%
# Out:
# matplotlib.patches.Arrow
